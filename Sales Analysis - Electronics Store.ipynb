# %% [markdown]
# **IMPORTING THE NECESSARY LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORTING AND CONCATENATING THE DATASET**

# %%
import os

# %%
Totalfile = [file for file in os.listdir("/Users/muralik/Desktop/SalesAnalysis/Sales_Data")]

# %%
Totalfile
# Out:
# ['Sales_December_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv']

# %%
All_files = pd.DataFrame()
for file in Totalfile:
    Df = pd.read_csv("/Users/muralik/Desktop/SalesAnalysis/Sales_Data/"+file)
    All_files = pd.concat([All_files,Df],ignore_index=True)
All_files.to_csv("All_Files.csv",index=False)

# %%
All_data = pd.read_csv("All_Files.csv")
All_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
All_data.drop_duplicates()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %%
All_data.isnull().count()
# Out:
# Order ID            186850
# Product             186850
# Quantity Ordered    186850
# Price Each          186850
# Order Date          186850
# Purchase Address    186850
# dtype: int64

# %% [markdown]
# **Question 1 : What was the best month for sales. In order to find this, we need to get the month column separately**

# %%
All_data["Month"] = All_data["Order Date"].str[0:2]
All_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %% [markdown]
# **Finding the NaN values in the data frame**

# %%
NaN_DataFrame = All_data[All_data.isna().any(axis=1)]
NaN_DataFrame
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 264         NaN     NaN              NaN        NaN        NaN
# 648         NaN     NaN              NaN        NaN        NaN
# 680         NaN     NaN              NaN        NaN        NaN
# 1385        NaN     NaN              NaN        NaN        NaN
# 1495        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185795      NaN     NaN              NaN        NaN        NaN
# 185868      NaN     NaN              NaN        NaN        NaN
# 185887      NaN     NaN              NaN        NaN        NaN
# 185960      NaN     NaN              NaN        NaN        NaN
# 186580      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address Month
# 264                 NaN   NaN
# 648                 NaN   NaN
# 680                 NaN   NaN
# 1385                NaN   NaN
# 1495                NaN   NaN
# ...

# %% [markdown]
# **Dropping the Nan values since, these rows have no data**

# %%
All_data = All_data.dropna(how="all")
All_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %% [markdown]
# **Error While converting Month Values to Int**
# **Debugging the error - invalid literal for int() with base 10: 'Or'**

# %%
Or_dataframe = All_data[All_data["Order Date"].str[0:2] == "Or"]
Or_dataframe
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 254     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 705     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1101    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2875    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3708    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 183671  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 184012  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 184041  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 184275  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186532  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address Month
# 254     Purchase Address    Or
# 705     Purchase Address    Or
# 1101    Purchase Address    Or
# ...

# %% [markdown]
# **So Instead of removing the data with Or, We are going to save the dataframe with Or**

# %%
All_data = All_data[All_data["Order Date"].str[0:2] != "Or"]
All_data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address Month
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001    12
# ...

# %% [markdown]
# **Now we are converting the Month field into integer**

# %%
All_data["Month"] = All_data["Month"].astype('int32')

# %%
All_data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address  Month
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001     12
# ...

# %% [markdown]
# **Question 1 : What was the best month for sales. We need to have a column called sales**

# %%
All_data["Sales"] = All_data["Quantity Ordered"].astype("int32") * All_data["Price Each"].astype("float64")

# %%
All_data.head(50)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    295665          Macbook Pro Laptop                1       1700
# 1    295666          LG Washing Machine                1      600.0
# 2    295667        USB-C Charging Cable                1      11.95
# 3    295668            27in FHD Monitor                1     149.99
# 4    295669        USB-C Charging Cable                1      11.95
# 5    295670       AA Batteries (4-pack)                1       3.84
# 6    295671        USB-C Charging Cable                1      11.95
# 7    295672        USB-C Charging Cable                2      11.95
# 8    295673  Bose SoundSport Headphones                1      99.99
# 9    295674      AAA Batteries (4-pack)                4       2.99
# 10   295675        USB-C Charging Cable                2      11.95
# 11   295676             ThinkPad Laptop                1     999.99
# 12   295677       AA Batteries (4-pack)                2       3.84
# ...

# %% [markdown]
# **Question 2 : Which US city saw the highest number of Sales**

# %%
All_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address  Month    Sales
# 0  136 Church St, New York City, NY 10001     12  1700.00
# 1     562 2nd St, New York City, NY 10001     12   600.00
# 2    277 Main St, New York City, NY 10001     12    11.95
# 3     410 6th St, San Francisco, CA 94016     12   149.99
# 4           43 Hill St, Atlanta, GA 30301     12    11.95

# %%
All_data.drop(columns="City")
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address  Month    Sales
# ...

# %%
def getstate(address):
    return address.split(",")[2].split(" ")[1]
def getcity(address):
    return address.split(",")[1]
#We are using split(",")[2].split(" ")[1] as there is a white space before the State

# %%
All_data["City"] = All_data["Purchase Address"].apply(lambda city: getcity(city) + " (" + getstate(city) + ') ')
All_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each  \
# 0   295665    Macbook Pro Laptop                1       1700
# 1   295666    LG Washing Machine                1      600.0
# 2   295667  USB-C Charging Cable                1      11.95
# 3   295668      27in FHD Monitor                1     149.99
# 4   295669  USB-C Charging Cable                1      11.95
#
#            Order Date                        Purchase Address  Month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12    11.95
#
#                    City  Hour  Minutes
# 0   New York City (NY)      0        1
# 1   New York City (NY)      7        3
# ...

# %% [markdown]
# **Question 2 : In Which City the highest number of Sales happened**

# %%
CitiesTally = All_data.groupby("City").sum()

# %%
CitiesTally
# Out:
#                        Month       Sales
# City
#  Atlanta (GA)         104794  2795498.58
#  Austin (TX)           69829  1819581.75
#  Boston (MA)          141112  3661642.01
#  Dallas (TX)          104620  2767975.40
#  Los Angeles (CA)     208325  5452570.80
#  New York City (NY)   175741  4664317.43
#  Portland (ME)         17144   449758.27
#  Portland (OR)         70621  1870732.34
#  San Francisco (CA)   315520  8262203.91
#  Seattle (WA)         104941  2747755.48

# %% [markdown]
# **Question 3 : What time should the advertisements be displayed to maximise product sales**

# %%
#For doing this, we need to get the hour and minute at which the order was made separately
All_data["Order Date"] = pd.to_datetime(All_data["Order Date"])

# %%
All_data["Hour"] = All_data["Order Date"].dt.hour
All_data["Minutes"] = All_data["Order Date"].dt.minute

# %%
Hours = [hour for hour,df in All_data.groupby("Hour")]

# %% [markdown]
# **Question 4: What are the products that are sold together**

# %%
Multiproductorders = All_data[All_data["Order ID"].duplicated(keep=False)]
Multiproductorders.head(20)
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 16    295681                Google Phone                1        600
# 17    295681        USB-C Charging Cable                1      11.95
# 18    295681  Bose SoundSport Headphones                1      99.99
# 19    295681            Wired Headphones                1      11.99
# 36    295698             Vareebadd Phone                1        400
# 37    295698        USB-C Charging Cable                2      11.95
# 42    295703       AA Batteries (4-pack)                1       3.84
# 43    295703  Bose SoundSport Headphones                1      99.99
# 66    295726                      iPhone                1        700
# 67    295726    Lightning Charging Cable                1      14.95
# 76    295735                      iPhone                1        700
# 77    295735    Apple Airpods Headphones                1        150
# 78    295735            Wired Headphones                1      11.99
# ...

# %%
Multiproductorders["Products Sold together"] = Multiproductorders.groupby("Order ID")["Product"].transform(lambda x: ",".join(x))
Multiproductorders.head()
# Out:
# /var/folders/y_/p61tjgy50cn618ls_r8mtps80000gn/T/ipykernel_1431/1722261944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Multiproductorders["Products Sold together"] = Multiproductorders.groupby("Order ID")["Product"].transform(lambda x: ",".join(x))
#    Order ID                     Product Quantity Ordered Price Each  \
# 16   295681                Google Phone                1        600
# 17   295681        USB-C Charging Cable                1      11.95
# 18   295681  Bose SoundSport Headphones                1      99.99
# 19   295681            Wired Headphones                1      11.99
# 36   295698             Vareebadd Phone                1        400
#
# ...

# %%
#Dropping the duplicates, since the product ID is occuring twice
Multiproductorders = Multiproductorders[["Order ID","Products Sold together"]].drop_duplicates()
Multiproductorders.head()
# Out:
#    Order ID                             Products Sold together
# 16   295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36   295698               Vareebadd Phone,USB-C Charging Cable
# 42   295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66   295726                    iPhone,Lightning Charging Cable
# 76   295735   iPhone,Apple Airpods Headphones,Wired Headphones

# %%
#Now we need to find out the most commonly bought products
from itertools import combinations
from collections import Counter
count = Counter()
for product in Multiproductorders["Products Sold together"]:
    ProductList = product.split(",")
    count.update(Counter(combinations(ProductList,2)))

# %%
for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# **Question 1 :In which month the best sales that has happened, we need to group the months together**

# %%
Results = All_data.groupby("Month").sum()

# %%
Months = ["Jan","Feb","Mar","Apr","May","June","July","Aug","Sep","Oct","Nov","Dec"]
plt.bar(Months,Results["Sales"])
plt.xlabel("Months")
plt.ylabel("Sales in US($) in Millions")
plt.show()

# %% [markdown]
# **Question 2 : In Which city the highest number of sales occurred**

# %%
city = [City for City, df in All_data.groupby("City")]
plt.bar(city,CitiesTally["Sales"])
plt.xticks(city,rotation= "vertical")
plt.xlabel("Cities")
plt.ylabel("Sales in US($) dollars in Millions")
plt.show()

# %% [markdown]
# **Question 3 : What time should the advertisements be displayed to maximise product sales**

# %%
plt.plot(Hours,All_data.groupby(["Hour"]).count())
plt.grid()
plt.xticks(Hours)
plt.xlabel("Hours")
plt.ylabel("No of products sold")
plt.show()
